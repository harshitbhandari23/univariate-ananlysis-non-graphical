# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitbhandari23/univariate-ananlysis-non-graphical/blob/main/univariate_analysisnongraphical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as snp
df=pd.read_csv("AB_NYC_2019.csv")
df.dropna(inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38821 entries, 0 to 48852
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   latitude                        38821 non-null  float64
#  7   longitude                       38821 non-null  float64
#  8   room_type                       38821 non-null  object
#  9   price                           38821 non-null  int64
#  10  minimum_nights                  38821 non-null  int64
#  11  number_of_reviews               38821 non-null  int64
# ...

# %%
df
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
df["id"]=df["id"].astype("str")
df["host_id"]=df["host_id"].astype("str")
df["latitude"]=df["latitude"].astype("str")
df["longitude"]=df["longitude"].astype("str")

# %% [markdown]
# # using describe

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  38821.000000    38821.000000       38821.000000       38821.000000
# mean     142.332526        5.869220          29.290255           1.373229
# std      196.994756       17.389026          48.182900           1.680328
# min        0.000000        1.000000           1.000000           0.010000
# 25%       69.000000        1.000000           3.000000           0.190000
# 50%      101.000000        2.000000           9.000000           0.720000
# 75%      170.000000        4.000000          33.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    38821.000000      38821.000000
# mean                         5.166611        114.886299
# std                         26.302954        129.529950
# min                          1.000000          0.000000
# ...

# %%
df.nunique()
# Out:
# id                                38821
# name                              38253
# host_id                           30232
# host_name                          9885
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# # categorical analysis

# %%
df["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Manhattan        16621
# Brooklyn         16439
# Queens            4572
# Bronx              875
# Staten Island      314
# Name: count, dtype: int64

# %%
df["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    20321
# Private room       17654
# Shared room          846
# Name: count, dtype: int64

# %%
df1=df["neighbourhood"].value_counts().reset_index()
df1
# Out:
#           neighbourhood  count
# 0          Williamsburg   3163
# 1    Bedford-Stuyvesant   3141
# 2                Harlem   2204
# 3              Bushwick   1942
# 4        Hell's Kitchen   1528
# ..                  ...    ...
# 213           Olinville      2
# 214      New Dorp Beach      2
# 215        Richmondtown      1
# 216           Rossville      1
# 217         Willowbrook      1
#
# [218 rows x 2 columns]

# %% [markdown]
# # neighbours with no.oh hotels greater than 1000

# %%
df1[df1["count"]>1000]
# Out:
#         neighbourhood  count
# 0        Williamsburg   3163
# 1  Bedford-Stuyvesant   3141
# 2              Harlem   2204
# 3            Bushwick   1942
# 4      Hell's Kitchen   1528
# 5        East Village   1489
# 6     Upper West Side   1482
# 7     Upper East Side   1405
# 8       Crown Heights   1265

# %% [markdown]
# # numerical analysis

# %%
df["price"].value_counts(bins=5)
# Out:
# (-10.001, 2000.0]    38786
# (2000.0, 4000.0]        20
# (4000.0, 6000.0]         8
# (8000.0, 10000.0]        5
# (6000.0, 8000.0]         2
# Name: count, dtype: int64

# %%
df["price"].mean()
# Out:
# np.float64(142.33252621004095)

# %%
df["price"].std()
# Out:
# np.float64(196.9947559183469)

# %%
df["price"].skew()
# Out:
# np.float64(23.673594295123014)

# %%
df["price"].kurt()
# Out:
# np.float64(953.4807356344945)

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.corr()
#
# File c:\Users\lenovo\anaconda_python\.venv\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\lenovo\anaconda_python\.venv\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# ...
